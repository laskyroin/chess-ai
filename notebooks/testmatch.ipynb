# %%
from chessai.arena import play_match
from chessai.search.policy import PolicyBot
from chessai.search.random_bot import RandomBot
from chessai.search.material import MaterialBot
import chess 
print(play_match(PolicyBot(ckpt_path="../runs/ckpt_32000.pt"), MaterialBot(seed=3), nbmatchs=100))
# Out:
# Policy vs material: 95.5 - 4.5

# %%
b = chess.Board()

# %%
b.push_san("Ra1#")

bot = PolicyBot(ckpt_path="../runs/ckpt.pt")
a = bot.select_move(b)
b.push(bot.select_move(b))
print(a)



# mat wins against random
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[80], line 4
#       1 b.push_san("Ra1#")
#       2
#       3 bot = PolicyBot(ckpt_path="../runs/ckpt.pt")
# ----> 4 a = bot.select_move(b)
#       5 b.push(bot.select_move(b))
#       6 print(a)
#       7
#
# File ~\info\chess-ai\src\chessai\search\policy.py:29, in PolicyBot.select_move(self, board)
#      27 moves = list(board.legal_moves)
#      28 idx = torch.tensor([move_to_index(m) for m in moves], device = y.device)
# ---> 29 best = moves[y.view(-1)[idx].argmax().item()]
#      30 return best
#
# IndexError: tensors used as indices must be long, int, byte or bool tensors
