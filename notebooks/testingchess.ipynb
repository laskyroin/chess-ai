# %%
import chess
b = chess.Board()
print(b)
print(len(list(b.legal_moves)))
b.push_san("e4")
print(b)
print(b.turn, b.fen())
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# 20
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# False rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Faure\AppData\Roaming\uv\python\cpython-3.14.3-windows-x86_64-none\python.exe
